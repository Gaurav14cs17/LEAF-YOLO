# %% [markdown]
# # 🍃 LEAF-YOLO Quick Start
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/your_username/LEAF-YOLO/blob/main/LEAF_YOLO_Quick_Start.ipynb)
#
# **Get started with LEAF-YOLO in 5 minutes!** ⚡
#
# This notebook shows you how to:
# - 🚀 **Install LEAF-YOLO** in Google Colab
# - 🎯 **Run object detection** on your images
# - 📊 **Try different model variants**
# - 💾 **Export models** for deployment
#
# **No training required** - use pre-trained models right away!

# %%
# Install LEAF-YOLO
print("🚀 Installing LEAF-YOLO...")
# !git clone https://github.com/your_username/LEAF-YOLO.git
# %cd LEAF-YOLO
# !pip install -r requirements.txt
print("✅ LEAF-YOLO installed successfully!")

# %%
# Upload and detect objects in your image
from google.colab import files
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("📁 Upload an image to detect objects in:")
uploaded = files.upload()

for filename in uploaded.keys():
    print(f"\\n🖼️  Processing: {filename}")
    
    # Read image
    image = cv2.imread(filename)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Run detection
    print("🔍 Running LEAF-YOLO detection...")
    results = model.predict(
        source=image_rgb,
        conf_thres=0.25,
        iou_thres=0.45,
        save=False,
        verbose=True
    )
    
    # Display results
    if len(results) > 0 and results[0].boxes is not None:
        num_detections = len(results[0].boxes)
        print(f"\\n🎯 Found {num_detections} objects!")
        
        # Show what was detected
        for i, box in enumerate(results[0].boxes):
            class_id = int(box.cls)
            confidence = float(box.conf)
            class_name = model.names[class_id]
            print(f"   {i+1}. {class_name}: {confidence:.2f} confidence")
        
        # Plot results
        result_img = results[0].plot()
        
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
        
        ax1.imshow(image_rgb)
        ax1.set_title(f"📷 Original Image ({filename})")
        ax1.axis('off')
        
        ax2.imshow(result_img)
        ax2.set_title(f"🎯 LEAF-YOLO Results ({num_detections} objects)")
        ax2.axis('off')
        
        plt.tight_layout()
        plt.show()
        
    else:
        print("\\n🔍 No objects detected in this image.")
        print("💡 Try lowering the confidence threshold or use a different image.")
        
        plt.figure(figsize=(10, 6))
        plt.imshow(image_rgb)
        plt.title(f"📷 {filename} (No objects detected)")
        plt.axis('off')
        plt.show()
    
    break
